# %%
import cv2
import numpy as np
import time
net = cv2.dnn.readNet("C:/Users/tarun/Desktop/yolov3 object detection/yolov3_training_last (1).weights", "C:/Users/tarun/Desktop/yolov3 object detection/yolo_custom_detection/yolov3_testing.cfg")
classes = ["ball"]
layer_names = net.getLayerNames()
output_layers = [layer_names[i - 1] for i in net.getUnconnectedOutLayers()]
camera = cv2.VideoCapture(0)

while True:
    _,image = camera.read()
    height, width, channels = image.shape

    # Detecting objects
    blob = cv2.dnn.blobFromImage(image, 0.00392, (320, 320), (0, 0, 0), True, crop=False)
    net.setInput(blob)
    outs = net.forward(output_layers)
    class_ids = []
    confidences = []
    boxes = []
    for out in outs:
        for detection in out:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]
            if confidence > 0.5:
                # Object detected
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)
                # Rectangle coordinates
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)
                boxes.append([x, y, w, h])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)

    font = cv2.FONT_HERSHEY_PLAIN
    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            label = str(classes[class_ids[i]])
            color = (0, 0, 255)
            cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
            cv2.putText(image, label, (x, y -10), font, 3, color, 3)
            tlc=(x,y)
            trc=(x+h,y)
            blc=(x,y+h)
            brc=(x+w,y+h)
            center=(center_x,center_y)
            height=h
            width=w
            print("Center of Box:",center,"Height and width:",(h,w),"Coordinates:",tlc,trc,blc,brc)        
    cv2.imshow("Image", image)
    key = cv2.waitKey(1)
    if key == 27:
        break
camera.release()
cv2.destroyAllWindows()
# Out:
# Center of Box: (104, 252) Height and width: (142, 129) Coordinates: (39, 181) (181, 181) (39, 323) (168, 323)
# Center of Box: (233, 197) Height and width: (252, 280) Coordinates: (93, 60) (345, 60) (93, 312) (373, 312)
# Center of Box: (356, 178) Height and width: (325, 417) Coordinates: (147, 15) (472, 15) (147, 340) (564, 340)
# Center of Box: (293, 202) Height and width: (403, 453) Coordinates: (67, 0) (470, 0) (67, 403) (520, 403)
# Center of Box: (325, 224) Height and width: (417, 489) Coordinates: (62, 20) (479, 20) (62, 437) (551, 437)
# Center of Box: (285, 229) Height and width: (419, 425) Coordinates: (77, 19) (496, 19) (77, 438) (502, 438)
# Center of Box: (268, 213) Height and width: (330, 457) Coordinates: (39, 48) (369, 48) (39, 378) (496, 378)
# Center of Box: (263, 223) Height and width: (350, 548) Coordinates: (-11, 48) (339, 48) (-11, 398) (537, 398)
# Center of Box: (266, 216) Height and width: (334, 522) Coordinates: (5, 49) (339, 49) (5, 383) (527, 383)
# Center of Box: (348, 86) Height and width: (196, 244) Coordinates: (226, -12) (422, -12) (226, 184) (470, 184)
# Center of Box: (321, 321) Height and width: (261, 285) Coordinates: (166, 189) (427, 189) (166, 450) (451, 450)
# Center of Box: (323, 314) Height and width: (258, 270) Coordinates: (179, 188) (437, 188) (179, 446) (449, 446)
# Center of Box: (322, 316) Height and width: (270, 275) Coordinates: (172, 182) (442, 182) (172, 452) (447, 452)
# Center of Box: (331, 325) Height and width: (257, 273) Coordinates: (194, 196) (451, 196) (194, 453) (467, 453)
# Center of Box: (392, 296) Height and width: (254, 296) Coordinates: (244, 169) (498, 169) (244, 423) (540, 423)
# Center of Box: (386, 312) Height and width: (296, 296) Coordinates: (228, 163) (524, 163) (228, 459) (524, 459)
# Center of Box: (373, 308) Height and width: (297, 313) Coordinates: (216, 159) (513, 159) (216, 456) (529, 456)
# Center of Box: (344, 313) Height and width: (301, 317) Coordinates: (185, 162) (486, 162) (185, 463) (502, 463)
# Center of Box: (343, 309) Height and width: (297, 301) Coordinates: (192, 160) (489, 160) (192, 457) (493, 457)
# Center of Box: (393, 302) Height and width: (276, 405) Coordinates: (190, 164) (466, 164) (190, 440) (595, 440)
# Center of Box: (567, 369) Height and width: (205, 137) Coordinates: (498, 266) (703, 266) (498, 471) (635, 471)
# Center of Box: (228, 124) Height and width: (265, 431) Coordinates: (12, -8) (277, -8) (12, 257) (443, 257)
# Center of Box: (268, 127) Height and width: (208, 390) Coordinates: (73, 23) (281, 23) (73, 231) (463, 231)
# Center of Box: (349, 362) Height and width: (154, 187) Coordinates: (255, 285) (409, 285) (255, 439) (442, 439)
# Center of Box: (303, 352) Height and width: (183, 166) Coordinates: (220, 260) (403, 260) (220, 443) (386, 443)
# Center of Box: (296, 352) Height and width: (163, 183) Coordinates: (204, 270) (367, 270) (204, 433) (387, 433)
# Center of Box: (282, 352) Height and width: (165, 188) Coordinates: (191, 273) (356, 273) (191, 438) (379, 438)
# Center of Box: (283, 312) Height and width: (182, 186) Coordinates: (190, 221) (372, 221) (190, 403) (376, 403)
# Center of Box: (282, 315) Height and width: (173, 196) Coordinates: (184, 228) (357, 228) (184, 401) (380, 401)
# Center of Box: (282, 315) Height and width: (170, 199) Coordinates: (182, 230) (352, 230) (182, 400) (381, 400)
# Center of Box: (283, 316) Height and width: (169, 202) Coordinates: (182, 231) (351, 231) (182, 400) (384, 400)
# Center of Box: (282, 318) Height and width: (176, 200) Coordinates: (182, 230) (358, 230) (182, 406) (382, 406)
# Center of Box: (282, 317) Height and width: (173, 209) Coordinates: (177, 230) (350, 230) (177, 403) (386, 403)
# Center of Box: (338, 256) Height and width: (298, 589) Coordinates: (43, 107) (341, 107) (43, 405) (632, 405)
# Center of Box: (344, 253) Height and width: (297, 678) Coordinates: (5, 104) (302, 104) (5, 401) (683, 401)
# Center of Box: (337, 255) Height and width: (301, 671) Coordinates: (1, 104) (302, 104) (1, 405) (672, 405)
